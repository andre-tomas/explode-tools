# %%
import explode-tool as et
# Out:
# Running cells with 'explode (Python 3.10.8)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'conda install -n explode ipykernel --update-deps --force-reinstall'
